# %%
import xarray as xr
import numpy as np
from pydap.client import open_url
from pydap.cas.urs import setup_session
#import regionmask

# %%
url = 'https://oceandata.sci.gsfc.nasa.gov:443/opendap/MODISA/L3SMI/2003/001/A2003001.L3m_DAY_CHL_chlor_a_9km.nc'
username = 'dahlia_dry'
password = 'MassTech2023'

# %%
try:
    session = setup_session(username,password,check_url=url)
    pydap_ds = open_url(url,session=session)
    store = xr.backends.PydapDataStore(pydap_ds)
    ds = xr.open_dataset(store)
except Exception as err:
    print(err)

def add_basin(data):
    atlantic = [2.0,6.0]
    pacific = [3.0,4.0]
    basins = regionmask.defined_regions.natural_earth.ocean_basins_50
    lon = np.arange(0.5, 360)
    lat = np.arange(89.5, -90, -1)
    mask = basins.mask(lon, lat)
    data= data.where(mask ==3 or mask ==4)
print(len(ds.chlor_a))
#add_basin(ds)
print(len(ds.chlor_a))
# Out:
# 2160
# 2160

# %%
print(df.head())

# %%
for jd in np.arange(1,366):
    url="https://oceandata.sci.gsfc.nasa.gov:443/opendap/MODISA/L3SMI/2003/" + '{:03d}'.format(jd) + "/A2003" + '{:03d}'.format(jd)+ ".L3m_DAY_CHL_chlor_a_9km.nc"
    print(url)
    try:
        session = setup_session(username,password,check_url=url)
        pydap_ds = open_url(url, session=session)
        store = xr.backends.PydapDataStore(pydap_ds)
        if jd==1:
            ds=xr.open_dataset(store).assign_coords({"time": jd})
        else:
            tmp=xr.open_dataset(store).assign_coords({"time": jd})
            ds=xr.concat([ds,tmp],dim="time")
    except Exception as err:
        print(jd)
        print(err)
# Out:
# https://oceandata.sci.gsfc.nasa.gov:443/opendap/MODISA/L3SMI/2003/001/A2003001.L3m_DAY_CHL_chlor_a_9km.nc
# https://oceandata.sci.gsfc.nasa.gov:443/opendap/MODISA/L3SMI/2003/002/A2003002.L3m_DAY_CHL_chlor_a_9km.nc
# https://oceandata.sci.gsfc.nasa.gov:443/opendap/MODISA/L3SMI/2003/003/A2003003.L3m_DAY_CHL_chlor_a_9km.nc
# https://oceandata.sci.gsfc.nasa.gov:443/opendap/MODISA/L3SMI/2003/004/A2003004.L3m_DAY_CHL_chlor_a_9km.nc
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-3f484f1a6852> in <module>
#      10         else:
#      11             tmp=xr.open_dataset(store).assign_coords({"time": jd})
# ---> 12             ds=xr.concat([ds,tmp],dim="time")
#      13     except Exception as err:
#      14         print(jd)
#
# ...

# %%
data =xr.open_dataset('test.nc')
print(data)
# Out:
# <xarray.Dataset>
# Dimensions:  ()
# Data variables:
#     *empty*
# Attributes: (12/48)
#     product_name:                      A2002185.L3b_DAY_CHL.nc
#     title:                             MODIS Level-3 Binned Data
#     instrument:                        MODIS
#     platform:                          Aqua
#     temporal_range:                    day
#     start_orbit_number:                885
#     ...                                ...
#     processing_level:                  L3 Binned
#     cdm_data_type:                     point
#     identifier_product_doi_authority:  http://dx.doi.org
#     identifier_product_doi:            10.5067/AQUA/MODIS/L3B/CHL/2018
#     keywords_vocabulary:               NASA Global Change Master Directory (G...
#     keywords:                          Earth Science > Oceans > Ocean Chemist...
